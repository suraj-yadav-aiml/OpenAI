# %%
from IPython.display import display,Image

# %%
import openai
from dotenv import dotenv_values

# %%
openai.api_key = dotenv_values('../.env')['OPENAI_API_KEY']

# %% [markdown]
# ## [Temperature - openai ref.](https://platform.openai.com/docs/api-reference/completions/create#completions/create-temperature)
# ## [Temperature](https://chat.openai.com/share/6c8f8aca-c7d1-4235-a8ca-9b9ed6ed2e2e)
#
# ### Defaults to 1
#
# **What sampling temperature to use, between 0 and 2. Higher values like 0.8 will make the output more random, while lower values like 0.2 will make it more focused and deterministic**

# %%
display(Image('img/3.png'))
display(Image('img/2.png'))
display(Image('img/4.png'))

# %%
response = openai.Completion.create(model = 'text-davinci-003',
                                    prompt = "Tell me a story",
                                    max_tokens = 200,
                                    temperature = 1)
print(response['choices'][0]['text'])
# Out:
# Once upon a time, there lived a sparkly fairy named Amethyst. She spent her days exploring the magical forest and collecting rocks and crystals with her friends. One day she discovered a special pink crystal with a magical power. Legend said that the crystal could grant its finder three wishes!
#
# Amethyst was so delighted, she quickly wished for the power of flight, and with a puff of pink smoke, glittery wings sprouted from her back. She was ecstatic and couldn't wait to share her newfound power with her friends!
#
# Amethyst's second wish was used to bring peace and harmony to the kingdom, and her third and final wish was for kindness to be spread throughout the kingdom and throughout the world.
#
# With those three simple wishes, Amethyst had made a huge difference in the world, and her magical pink crystal will always remain a reminder to her of the power of kindness.

# %% [markdown]
# ***

# %%
response = openai.Completion.create(model = 'text-davinci-003',
                                    prompt = "Tell me a story",
                                    max_tokens = 200,
                                    temperature = 2)
print(response['choices'][0]['text'])
# Out:
#  chēķama Hailey and Omar liked guseames pieces Mahing tapenge teru akharinho dijeni bun bangbur Ahometino Huseno. Zakfo bandoro denascoursina penicho chicrikorka, lotanic mariam gevicumica hamofi estindena Freriadset Sekregustiro Amenano Charischristiharffolog taä bra peñson samugerem sen Kasback Blafchegar Venafcla.
#
# Haiety andrar pandagingukuen Belove Ta arpesst moriso hadcomfee ahutorlu Bluminphasgre percon destidas Lindrosczoones Molii Azekbaloos brōbygenear pesturi kalexiascures va Croorth Pastagaardium Nilgen Hadarmame Tinabeagos arghendaf Enintremere Laurmis racism Taskeoossbet Baldonaia Cardico ceago Josatitude jinekaber

# %% [markdown]
# ***

# %%
response = openai.Completion.create(model = 'text-davinci-003',
                                    prompt = "Tell me a story",
                                    max_tokens = 100,
                                    temperature = 0)
print(response['choices'][0]['text'])
# Out:
# Once upon a time, there was a young girl named Sarah. She lived in a small village with her family. Sarah was a very curious girl and loved to explore the world around her.
#
# One day, Sarah decided to go on an adventure and explore the nearby forest. She packed a bag with some food and water and set off. As she walked through the forest, she noticed a strange light coming from a clearing. She decided to investigate and found a magical pond.

# %%
response = openai.Completion.create(model = 'text-davinci-003',
                                    prompt = "Tell me a story",
                                    max_tokens = 100,
                                    temperature = 0)
print(response['choices'][0]['text'])
# Out:
# Once upon a time, there was a young girl named Sarah who lived in a small village. She was a kind and gentle soul, and she was loved by all who knew her.
#
# One day, Sarah decided to take a walk in the nearby forest. As she walked, she noticed a small, white rabbit hopping along the path. She followed the rabbit, and soon found herself in a magical clearing.
#
# In the center of the clearing was a large, old tree.

# %%
response = openai.Completion.create(model = 'text-davinci-003',
                                    prompt = "Tell me a story",
                                    max_tokens = 100,
                                    temperature = 0)
print(response['choices'][0]['text'])
# Out:
# Once upon a time, there was a young girl named Sarah who lived in a small village. She was a kind and gentle soul, but she was often overlooked by the other villagers.
#
# One day, Sarah decided to take a walk in the nearby forest. As she walked, she noticed a small, white rabbit hopping along the path. She followed the rabbit until it stopped at the entrance of a small, hidden cave.
#
# Curious, Sarah stepped inside and was amazed by

# %% [markdown]
# ***

# %%
response = openai.Completion.create(model = 'text-davinci-003',
                                    prompt = "My favorite animal is a ",
                                    max_tokens = 100,
                                    temperature = 0)
print(response['choices'][0]['text'])
# Out:
# dog. Dogs are loyal, loving, and make great companions. They are also very intelligent and can be trained to do a variety of tasks. Dogs are also great for providing emotional support and companionship.

# %%
response = openai.Completion.create(model = 'text-davinci-003',
                                    prompt = "My favorite animal is a ",
                                    max_tokens = 100,
                                    temperature = 0)
print(response['choices'][0]['text'])
# Out:
# dog. Dogs are loyal, loving, and make great companions. They are also very intelligent and can be trained to do a variety of tasks. Dogs are also great for providing emotional support and companionship.

# %% [markdown]
# ***

# %%
response = openai.Completion.create(model = 'text-davinci-003',
                                    prompt = "My favorite animal is a ",
                                    max_tokens = 100,
                                    temperature = 0.7)
print(response['choices'][0]['text'])
# Out:
# dog. Dogs are loyal and loving companions that can provide lots of joy and entertainment. They are also incredibly intelligent and can be trained to do incredible things. My dog is my best friend and I love spending time with him.

# %%
response = openai.Completion.create(model = 'text-davinci-003',
                                    prompt = "My favorite animal is a ",
                                    max_tokens = 100,
                                    temperature = 0.7)
print(response['choices'][0]['text'])
# Out:
# dog. Dogs are known to be loyal, loving, and protective companions. They are also very smart and can be trained to do a variety of tasks. Dogs can provide emotional support for their owners and can even help with medical conditions. I love spending time with my dog and enjoy teaching him new tricks.

# %%
response = openai.Completion.create(model = 'text-davinci-003',
                                    prompt = "My favorite animal is a ",
                                    max_tokens = 100,
                                    temperature = 0.9)
print(response['choices'][0]['text'])
# Out:
# cat.

# %%
response = openai.Completion.create(model = 'text-davinci-003',
                                    prompt = "My favorite animal is a ",
                                    max_tokens = 100,
                                    temperature = 1)
print(response['choices'][0]['text'])
# Out:
# penguin.

# %%
response = openai.Completion.create(model = 'text-davinci-003',
                                    prompt = "My favorite animal is a ",
                                    max_tokens = 100,
                                    temperature = 1.2)
print(response['choices'][0]['text'])
# Out:
#  Deer.
#
# Deer are social animals that form herds to feed and travel in. They are herbivorous, eating fresh green vegetation along with nuts, nuts leaves and fruits. The unique coats of males, known as bucks, generally range from reddish brown to grey. Females, called does, usually have lighter color coats. Deer are also known for their graceful disposal while running and can travel from 30-35 mph for a short charge if necessary.

# %% [markdown]
# ***

# %% [markdown]
# # [Top p - openai-ref.](https://platform.openai.com/docs/api-reference/completions/create#completions/create-top_p)
# ### Optional ,  Defaults to 1

# %%
display(Image('img/5.png'))
display(Image('img/1.png'))

# %% [markdown]
# <p><font size="4">The <strong>"Top p"</strong> parameter, also known as the <strong>"nucleus"</strong> or <strong>"top probability"</strong> parameter, is a feature used in the ChatGPT API that helps control the randomness and diversity of the generated responses. It allows you to set a threshold probability value, and only the most probable tokens that cumulatively exceed this probability are considered during response generation.</font></p>
# <p><font size="4">To explain it in simple terms, let's say the <strong>"Top p"</strong> parameter is set to <strong>0.8</strong>. During response generation, the model considers the probability distribution of the next possible tokens based on the context provided. It then calculates the cumulative probability of these tokens from the most probable to the least probable. It keeps adding up the probabilities until the sum exceeds the threshold set by the <strong>"Top p"</strong> value (<strong>0.8</strong> in this example). The model then samples from this narrowed-down set of tokens to choose the next word in the response.</font></p>
# <p><font size="4">Here are five detailed examples to illustrate how the <strong>"Top p"</strong> parameter works:</font></p>
# <ol>
#   <li>
#     <font size="4"><strong>Example with "Top p" set to 0.8:</strong><br>
#     Suppose the model generates the following probabilities for the next tokens: [<strong>0.3</strong>, <strong>0.2</strong>, <strong>0.15</strong>, <strong>0.1</strong>, <strong>0.05</strong>, <strong>0.04</strong>, <strong>0.03</strong>]. The cumulative probabilities would be: [<strong>0.3</strong>, <strong>0.5</strong>, <strong>0.65</strong>, <strong>0.75</strong>, <strong>0.8</strong>, 0.84, 0.87]. Since the cumulative probability exceeds 0.8 after considering the first five tokens, only those tokens are eligible for sampling, and the model chooses from them.</font></li>
#   <li>
#     <font size="4"><strong>Example with "Top p" set to 0.5:</strong><br>
#     Suppose the probabilities for the next tokens are: [<strong>0.4</strong>, <strong>0.25</strong>, <strong>0.2</strong>, 0.05, 0.03, 0.02, 0.01]. The cumulative probabilities would be: [<strong>0.4</strong>, <strong>0.65</strong>, <strong>0.85</strong>, 0.9, 0.93, 0.95, 0.96]. Here, the cumulative probability exceeds 0.5 after considering the first three tokens. Thus, the model only samples from those three tokens.</font></li>
#   <li>
#     <font size="4"><strong>Example with "Top p" set to 0.2:</strong><br>
#     If the probabilities for the next tokens are: [<strong>0.1</strong>, <strong>0.09</strong>, 0.08, 0.07, 0.06, 0.05, 0.04], the cumulative probabilities would be: [<strong>0.1</strong>, <strong>0.19</strong>, <strong>0.27</strong>, 0.34, 0.4, 0.45, 0.49]. As the cumulative probability surpasses 0.2 after the second token, only the first two tokens are eligible for sampling.</font></li>
#   <li>
#     <font size="4"><strong>Example with "Top p" set to 1.0 (No truncation):</strong><br>
#     If the probabilities for the next tokens are: [<strong>0.3</strong>, <strong>0.2</strong>, <strong>0.15</strong>, <strong>0.1</strong>, <strong>0.05</strong>, <strong>0.04</strong>, <strong>0.03</strong>], the cumulative probabilities would be: [<strong>0.3</strong>, <strong>0.5</strong>, <strong>0.65</strong>, <strong>0.75</strong>, <strong>0.8</strong>, 0.84, 0.87]. Since the cumulative probability exceeds 1.0 after considering all the tokens, no truncation occurs, and the model samples from all the tokens.</font></li>
#   <li>
#     <font size="4"><strong>Example with "Top p" set to 0.0 (No sampling):</strong><br>
#     In this case, regardless of the probabilities assigned to the next tokens, the <strong>"Top p"</strong> value is 0.0, which means no tokens are considered for sampling. The model would always choose the most probable token as the next word, resulting in deterministic responses.</font></li>
# </ol>
# <p><font size="4">Remember, adjusting the <strong>"Top p"</strong> parameter can influence the randomness and creativity of the generated responses, allowing you to control the balance between coherent and unexpected outputs.</font></p>

# %% [markdown]
# #### OpenAI reference :
# #### top_p :
# An alternative to sampling with temperature, called nucleus sampling, where the model considers the results of the tokens with top_p probability mass. So 0.1 means only the tokens comprising the top 10% probability mass are considered.
# **We generally recommend altering `top_p` or `temperature` but not both.**

# %%
import textwrap

# %%
def nice_print(dictionary):
    for key, value in dictionary.items():
        print(f"{key}:")
        print("\n".join(textwrap.wrap(value,width=120)))
        print("-"*120)

# %%
nice_print(
    {
        f"Top p {top_p}": openai.Completion.create(
            model = 'text-davinci-003',
            prompt = """My favorite food is""".strip(),
            max_tokens = 50,
            echo = True,
            top_p=top_p
        )['choices'][0]['text']
        .strip()
        for top_p in [1, 0.5, 0]
    }
)
# Out:
# Top p 1:
# My favorite food is sushi. Sushi is a Japanese dish that consists of small pieces of raw fish or seafood, combined with
# other ingredients such as rice, vegetables, and sometimes fruit. I love sushi because it is fresh and flavorful, and
# there is a wide variety of
# ------------------------------------------------------------------------------------------------------------------------
# Top p 0.5:
# My favorite food is pizza. I love the combination of cheese, sauce, and crust. It's also very versatile, as you can top
# it with a variety of ingredients. I especially love a classic pepperoni pizza, but I also enjoy trying new toppings like
# art
# ------------------------------------------------------------------------------------------------------------------------
# Top p 0:
# My favorite food is pizza. I love the combination of the doughy crust, the tangy tomato sauce, and the melty cheese. I
# ...

# %%
def nice_print_2(dictionary):
    for key, value in dictionary.items():
        print(f"{key}:")
        print(textwrap.fill(value,width=120))
        print("-"*120)

# %%
nice_print_2(
    {
        f"Top p {top_p}": openai.Completion.create(
            model = 'text-davinci-003',
            prompt = """My favorite food is""".strip(),
            max_tokens = 50,
            echo = True,
            top_p=top_p
        )['choices'][0]['text']
        .strip()
        for top_p in [1, 0.5, 0]
    }
)
# Out:
# Top p 1:
# My favorite food is steak. I love the flavor and the texture of steak. I like how it can be cooked in different ways to
# bring out the flavors. I also like its classic meaty flavor that pairs well with other ingredients. Steak also has a
# great amount
# ------------------------------------------------------------------------------------------------------------------------
# Top p 0.5:
# My favorite food is pizza. I love the combination of the melted cheese, the flavorful sauce, and the variety of
# toppings. It's a great way to satisfy a craving for something savory and delicious. Plus, it's a great way to get
# together with friends
# ------------------------------------------------------------------------------------------------------------------------
# Top p 0:
# My favorite food is pizza. I love the combination of the doughy crust, the tangy tomato sauce, and the melty cheese. I
# ...

# %% [markdown]
# ***

# %% [markdown]
# # [frequency_penalty - OpenAI Ref.](https://platform.openai.com/docs/api-reference/completions/create#completions/create-frequency_penalty)
# ### number  ,   Optional  ,  Defaults to 0
# ```
# Number between -2.0 and 2.0. Positive values penalize new tokens based on their existing frequency in the text so far, decreasing the model's likelihood to repeat the same line verbatim.
# ```
# [See more information about frequency and presence penalties.](https://platform.openai.com/docs/api-reference/parameter-details)

# %%
display(Image('img/6.png'))
display(Image('img/7.png'))

# %% [markdown]
# ```
# The "frequency_penalty" parameter in ChatGPT is used to control the repetitiveness of responses generated by the model. It encourages or discourages the model from repeating the same or similar phrases in its output. By adjusting the frequency penalty value, you can influence how likely the model is to generate repetitive responses.
# ```

# %% [markdown]
# <font size="4">
# <p>
# - The "<strong>frequency_penalty</strong>" parameter is a setting that you can use when interacting with ChatGPT to control the generation of repetitive or overly frequent responses.<br><br>
# - It helps to adjust the model's tendency to repeat certain phrases or responses frequently, making the generated conversation more varied and diverse.<br><br>
# - The value of "<strong>frequency_penalty</strong>" can range from -2 to 2. A lower value like -2 encourages the model to produce more repetitive responses, while a higher value like 2 discourages repetition and encourages more unique and novel responses.<br><br>
# - A value of 0 (default) indicates no special preference for or against repetitive responses, and the model will generate based on its inherent biases.<br><br>
# - A positive value above 0 increases the penalty on repetitive responses, making them less likely to be generated. This can help in situations where you want more originality in the model's output.<br><br>
# - Conversely, a negative value below 0 decreases the penalty on repetitive responses, making them more likely to occur. This can be useful if you want the model to be more consistent or if repetition is acceptable or desired in the context.<br>
# - The actual impact of the "<strong>frequency_penalty</strong>" setting can vary depending on the specific conversation and the other parameters used. It may not completely eliminate repetition, but it can influence the likelihood of repetitive responses.<br><br>
# - It's important to experiment with different values of "<strong>frequency_penalty</strong>" to find the balance that suits your desired output and the nature of the conversation you're having with ChatGPT.
# </p>
# </font>

# %%
def nice_print(dictionary):
    for key, value in dictionary.items():
        print(f"{key}:")
        print(textwrap.fill(value,width=120))
        print("-"*120)

# %%
nice_print(
    {
        f"Frequency Penalty {x}": openai.Completion.create(
            model="text-davinci-003",
            prompt="""The first 15 elements are Hydrogen, Helium,""".strip(),
            max_tokens=200,
            echo=True,
            frequency_penalty=x,
        )['choices'][0]["text"]
        .strip()
        for x in [-2, -1, 0, 1, 2]
    }
)
# Out:
# Frequency Penalty -2:
# The first 15 elements are Hydrogen, Helium, Lithium, Beryllium, Boron, Carbon, Nitrogen, Oxygen, Fluorine, Neon, Sodium,
# Magnesium,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ------------------------------------------------------------------------------------------------------------------------
# Frequency Penalty -1:
# The first 15 elements are Hydrogen, Helium, Lithium, Beryllium, Boron, Carbon, Nitrogen, Oxygen, Fluorine, Neon, Sodium,
# Magnesium, Aluminum, Silicon, Phosphorus, Sulfur, Chlorine,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
# ------------------------------------------------------------------------------------------------------------------------
# Frequency Penalty 0:
# ...

# %% [markdown]
# ***
